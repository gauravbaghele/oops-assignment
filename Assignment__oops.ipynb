# %% [markdown]
# #Assignment -> **OOPS Python**
#
# ---

# %% [markdown]
# #THEORATICAL QUESTIONS
#
# ---
#
#
# ##Question 1. What is Object-Oriented Programming (OOP)?
#
# OOP is a programming paradigm based on the concept of objects that contain data (attributes) and functions (methods).
# It helps structure programs into reusable, modular components.
#
# ##Question 2. What is a class in OOP?
#
# A class is a blueprint for creating objects.
# It defines the attributes and methods that the created objects will have.
#
# ##Question 3. What is an object in OOP?
#
# An object is an instance of a class.
# It represents a real-world entity and uses the class blueprint to store data and perform actions.
#
# ##Question 4. Difference between abstraction and encapsulation.
#
# Abstraction means showing only the essential details and hiding the unnecessary ones.
#
# Encapsulation means hiding the internal data of a class and protecting it from direct access.
#
# Focuses on data security
# Achieved using private variables and getter/setter methods
#
# ##Question 5. What are dunder methods in Python?
#
# Dunder (double-underscore) methods are special methods with names like __init__, __str__, __add__.
# They enable operator overloading and customize class behavior.
#
# ##Question 6. Explain inheritance in OOP
#
# Inheritance allows one class (child) to acquire properties and methods of another class (parent).
# It promotes code reuse and hierarchical structure.
#
# ##Question 7. What is polymorphism in OOP?
#
# Polymorphism means many forms.
# It allows the same function name to behave differently depending on the object.
#
# Example: len("abc") and len([1,2]) work differently.
#
# ##Question 8. How is encapsulation achieved in Python?
#
# Through:
#
# Private variables: __balance
#
# Getter and setter methods
#
# Property decorators
#
# ##Question 9. What is a constructor in Python?
#
# A special method __init__() that runs automatically when an object is created.
#
# ##Question 10. What are class and static methods in Python?
#
# Class method (@classmethod) → Accesses class-level data (cls)
#
# Static method (@staticmethod) → Utility function, doesn’t access class or object data
#
# ##Question 11. What is method overloading in Python?
#
# Python does not support traditional overloading.
# But we mimic it using default arguments or *args.
#
# ##Question 12. What is method overriding in OOP?
#
# When a child class redefines a method of its parent class with the same name.
#
# ##Question 13. What is a property decorator in Python?
#
# @property is used to convert a method into a read-only attribute and implement getters/setters.
#
# ##Question 14. Why is polymorphism important?
#
# Increases flexibility
#
# Supports code reusability
#
# Same interface, different implementations
#
# ##Question 15. What is an abstract class in Python?
#
# A class with at least one abstract method, defined using abc module.
# Cannot be instantiated.
#
# ##Question 16. Advantages of OOP
#
# Modularity
#
# Reusability
#
# Easy debugging
#
# Data security (Encapsulation)
#
# Flexibility (Polymorphism)
#
# ##Question 17. Difference between class variable & instance variable.
#
# Class Variable	Instance Variable
# Shared by all objects	Unique to each object
# Defined outside constructor	Defined inside constructor
#
# ##Question 18. What is multiple inheritance in Python?
#
# A class can inherit from multiple parent classes.
# Example: class C(A, B):
#
# ##Question 19. Purpose of __str__ and __repr__
#
# __str__ → User-friendly string representation
#
# __repr__ → Developer/Debug representation (should recreate object)
#
# ##Question 20. Significance of super()
#
# Used to call parent class methods inside child classes, especially in method overriding.
#
# ##Question 21. Significance of __del__
#
# Destructor method called when an object is destroyed (rarely used in Python).
#
# ##Question 22. Difference between @staticmethod and @classmethod.
#
# @staticmethod	@classmethod
# No access to class/object data	Access to class data
# Behaves like normal function	Uses cls as first argument
#
# ##Question 23. How polymorphism works with inheritance in Python
#
# Child classes override parent class methods, and Python automatically calls the appropriate method at runtime.
#
# ##Question 24. Method chaining in Python
#
# Returning self from methods allows multiple operations in a single line.
#
# Example:
# obj.setA().setB().setC()
#
# ##Question 25. Purpose of __call__ method
#
# Allows an object to be called like a function.
#
# Example:
# obj()

# %% [markdown]
# #**PRACTICAL QUESTIONS**
#
# ---

# %%
"""Question 1- Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
that overrides the speak() method to print "Bark!"""
class Animal:
    def speak(self):
        print("Generic animal sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

if __name__ == "__main__":
    d = Dog()
    d.speak()
# Out:
# Bark!

# %%
"""#Question 2-  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both."""
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, r):
        self.r = r
    def area(self):
        return 3.14 * self.r * self.r

class Rectangle(Shape):
    def __init__(self, l, b):
        self.l = l
        self.b = b
    def area(self):
        return self.l * self.b

if __name__ == "__main__":
    c = Circle(5)
    r = Rectangle(4, 6)
    print("Circle area:", c.area())
    print("Rectangle area:", r.area())
# Out:
# Circle area: 78.5
# Rectangle area: 24

# %%
"""Question 3- Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute."""
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

if __name__ == "__main__":
    e = ElectricCar("Four Wheeler", "Tesla", "80 kWh")
    print(e.type, e.brand, e.battery)
# Out:
# Four Wheeler Tesla 80 kWh

# %%
"""Question 4- Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
Sparrow and Penguin that override the fly() method.
"""
class Bird:
    def fly(self):
        print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies fast")

class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly")

if __name__ == "__main__":
    birds = [Sparrow(), Penguin()]
    for b in birds:
        b.fly()
# Out:
# Sparrow flies fast
# Penguins cannot fly

# %%
"""Question 5-  Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
balance and methods to deposit, withdraw, and check balance."""
class BankAccount:
    def __init__(self):
        self.__balance = 0

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount

    def check_balance(self):
        return self.__balance

if __name__ == "__main__":
    b = BankAccount()
    b.deposit(1000)
    b.withdraw(300)
    print("Balance:", b.check_balance())
# Out:
# Balance: 700

# %%
"""Question 6- Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
and Piano that implement their own version of play()."""
class Instrument:
    def play(self):
        print("Generic sound")

class Guitar(Instrument):
    def play(self):
        print("Playing Guitar")

class Piano(Instrument):
    def play(self):
        print("Playing Piano")

if __name__ == "__main__":
    instruments = [Guitar(), Piano()]
    for i in instruments:
        i.play()
# Out:
# Playing Guitar
# Playing Piano

# %%
"""Question 7-  Create a class MathOperations with a class method add_numbers() to add two numbers and a static
method subtract_numbers() to subtract two numbers."""
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

if __name__ == "__main__":
    print(MathOperations.add_numbers(5, 3))
    print(MathOperations.subtract_numbers(10, 4))
# Out:
# 8
# 6

# %%
"""Question 8-  Implement a class Person with a class method to count the total number of persons created."""
class Person:
    count = 0

    def __init__(self):
        Person.count += 1

if __name__ == "__main__":
    p1 = Person()
    p2 = Person()
    p3 = Person()
    print("Total persons:", Person.count)
# Out:
# Total persons: 3

# %%
"""Question 9- Write a class Fraction with attributes numerator and denominator. Override the str method to display the
fraction as "numerator/denominator."""
class Fraction:
    def __init__(self, n, d):
        self.n = n
        self.d = d

    def __str__(self):
        return f"{self.n}/{self.d}"

if __name__ == "__main__":
    f = Fraction(3, 4)
    print(f)
# Out:
# 3/4

# %%
"""Question 10- Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
vectors."""
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

if __name__ == "__main__":
    v1 = Vector(2, 3)
    v2 = Vector(4, 1)
    v3 = v1 + v2
    print(v3)
# Out:
# (6, 4)

# %%
"""Question 11- Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
{name} and I am {age} years old."""
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

if __name__ == "__main__":
    p = Person("gaurav", 23)
    p.greet()
# Out:
# Hello, my name is gaurav and I am 23 years old.

# %%
"""Question 12- Implement a class Student with attributes name and grades. Create a method average_grade() to compute
the average of the grades."""
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

if __name__ == "__main__":
    s = Student("Amit", [80, 90, 85])
    print("Average:", s.average_grade())
# Out:
# Average: 85.0

# %%
"""Question 13- Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
area."""
class Rectangle:
    def set_dimensions(self, l, b):
        self.l = l
        self.b = b

    def area(self):
        return self.l * self.b

if __name__ == "__main__":
    r = Rectangle()
    r.set_dimensions(5, 4)
    print("Area:", r.area())
# Out:
# Area: 20

# %%
"""Question 14- Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary."""
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus):
        return super().calculate_salary(hours, rate) + bonus

if __name__ == "__main__":
    m = Manager()
    print("Salary:", m.calculate_salary(40, 100, 5000))
# Out:
# Salary: 9000

# %%
"""Question 15- Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
calculates the total price of the product."""
class Product:
    def __init__(self, name, price, qty):
        self.name = name
        self.price = price
        self.qty = qty

    def total_price(self):
        return self.price * self.qty

if __name__ == "__main__":
    p = Product("Laptop", 50000, 2)
    print("Total Price:", p.total_price())
# Out:
# Total Price: 100000

# %%
"""Question 16- Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
implement the sound() method"""
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

if __name__ == "__main__":
    a1 = Cow()
    a2 = Sheep()
    a1.sound()
    a2.sound()
# Out:
# Moo
# Baa

# %%
"""Question 17- Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
returns a formatted string with the book's details."""
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def get_book_info(self):
        return f"{self.title} by {self.author} ({self.year})"

if __name__ == "__main__":
    b = Book("Python 101", "John Doe", 2020)
    print(b.get_book_info())
# Out:
# Python 101 by John Doe (2020)

# %%
"""Question 18- Create a class House with attributes address and price. Create a derived class Mansion that adds an
attribute number_of_rooms"""
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, rooms):
        super().__init__(address, price)
        self.rooms = rooms

if __name__ == "__main__":
    m = Mansion("MG Road", 5000000, 12)
    print(m.address, m.price, m.rooms)
# Out:
# MG Road 5000000 12
